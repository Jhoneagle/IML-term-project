# %% [markdown]
# # Overview of experiment results

# %%
import pandas as pd

# %% [markdown]
# # First iteration

# %% [markdown]
# ## Load data

# %% [markdown]
# ### Binary data

# %%
all_binary = pd.read_csv('../data/experiment_first_round/CV_binary_all_data.csv', index_col="model_name")
means_binary = pd.read_csv('../data/experiment_first_round/CV_binary_mean_data.csv', index_col="model_name")
std_binary = pd.read_csv('../data/experiment_first_round/CV_binary_std_data.csv', index_col="model_name")

# %% [markdown]
# ### Multi-class data

# %%
all_multinomial = pd.read_csv('../data/experiment_first_round/CV_multinomial_all_data.csv', index_col="model_name")
means_multinomial = pd.read_csv('../data/experiment_first_round/CV_multinomial_mean_data.csv', index_col="model_name")
std_multinomial = pd.read_csv('../data/experiment_first_round/CV_multinomial_std_data.csv', index_col="model_name")

# %% [markdown]
# ## Overview

# %% [markdown]
# ### Binary data

# %%
all_binary.describe()

# %%
means_binary.describe()

# %%
std_binary.describe()

# %% [markdown]
# ### Multi-class data

# %%
all_multinomial.describe()
# Out:
#        accuracy_mean  accuracy_std  accuracy_scaled_mean  accuracy_scaled_std
# count     154.000000    154.000000            154.000000           154.000000
# mean        0.533928      0.039952              0.583799             0.039429
# std         0.135123      0.031063              0.070312             0.022714
# min         0.060465      0.000000              0.226047             0.000000
# 25%         0.500000      0.031599              0.523081             0.032970
# 50%         0.568605      0.042488              0.604535             0.041541
# 75%         0.610000      0.047865              0.643023             0.046688
# max         0.660465      0.257138              0.674186             0.150952

# %%
means_multinomial.describe()
# Out:
#        accuracy_mean  accuracy_std  accuracy_scaled_mean  accuracy_scaled_std
# count     154.000000    154.000000            154.000000           154.000000
# mean        0.552711      0.044736              0.597300             0.041696
# std         0.107747      0.039614              0.069127             0.021864
# min         0.060465      0.000000              0.164419             0.000000
# 25%         0.527674      0.034998              0.567965             0.036437
# 50%         0.572093      0.042734              0.613837             0.041241
# 75%         0.614186      0.049166              0.640814             0.047607
# max         0.662791      0.257627              0.676047             0.156960

# %%
std_multinomial.describe()
# Out:
#        accuracy_mean  accuracy_std  accuracy_scaled_mean  accuracy_scaled_std
# count     154.000000    154.000000            154.000000           154.000000
# mean        0.546684      0.040622              0.551942             0.037932
# std         0.052517      0.021281              0.066422             0.016512
# min         0.294419      0.000000              0.107907             0.000000
# 25%         0.506686      0.038350              0.527442             0.033550
# 50%         0.555349      0.042963              0.565581             0.040474
# 75%         0.584186      0.048629              0.595349             0.046277
# max         0.626977      0.163924              0.623023             0.106940

# %% [markdown]
# ## Top classifiers in unscaled accuracy

# %% [markdown]
# ### Binary data

# %%
all_binary.sort_values(['accuracy_mean'], ascending = False)
# Out:
#                     accuracy_mean  accuracy_std  accuracy_scaled_mean  \
# model_name
# ada_kbestmutual          0.871628      0.040745              0.871860
# ada                      0.870930      0.034120              0.871395
# ada_kbest                0.869767      0.038142              0.871395
# svcLinear_rfe            0.866047      0.035593              0.863488
# ada_rfe                  0.865581      0.032902              0.864651
# ...                           ...           ...                   ...
# mlp_kpca                 0.500000      0.000000              0.518837
# gaussian_kpca            0.500000      0.000000              0.754186
# logistic_kpca            0.500000      0.000000              0.540000
# rfc_kpca                 0.500000      0.000000              0.503721
# decissionTree_kpca       0.500000      0.000000              0.500930
#
#                     accuracy_scaled_std
# model_name
# ada_kbestmutual                0.040380
# ...

# %%
means_binary.sort_values(['accuracy_mean'], ascending = False)
# Out:
#                     accuracy_mean  accuracy_std  accuracy_scaled_mean  \
# model_name
# ada                      0.871163      0.034638              0.870233
# ada_rfe                  0.868837      0.026520              0.861163
# rfc_select               0.861628      0.033318              0.824651
# ada_select               0.859070      0.032859              0.861163
# gaussian_lda             0.857674      0.035844              0.857674
# ...                           ...           ...                   ...
# svc_kpca                 0.500000      0.000000              0.767442
# mlp_kpca                 0.500000      0.000000              0.753721
# svcLinear_kpca           0.500000      0.000000              0.672326
# ada_kpca                 0.500000      0.000000              0.620233
# decissionTree_kpca       0.500000      0.000000              0.606977
#
#                     accuracy_scaled_std
# model_name
# ada                            0.034600
# ...

# %%
std_binary.sort_values(['accuracy_mean'], ascending = False)
# Out:
#                       accuracy_mean  accuracy_std  accuracy_scaled_mean  \
# model_name
# gaussian_llemodified       0.824419      0.041422              0.808140
# mlp_select                 0.823023      0.038234              0.826977
# gaussian_select            0.819535      0.037516              0.818140
# svcLinear_select           0.816047      0.038754              0.812791
# mlp_llemodified            0.813256      0.037672              0.803023
# ...                             ...           ...                   ...
# qda_kpca                   0.500233      0.001628              0.539767
# gaussianNB_kpca            0.500000      0.000000              0.591163
# ada_kpca                   0.500000      0.000000              0.530930
# rfc_kpca                   0.500000      0.000000              0.508372
# decissionTree_kpca         0.500000      0.000000              0.533953
#
#                       accuracy_scaled_std
# model_name
# ...

# %% [markdown]
# ### Multi-class data

# %%
all_multinomial.sort_values(['accuracy_mean'], ascending = False)
# Out:
#                       accuracy_mean  accuracy_std  accuracy_scaled_mean  \
# model_name
# svcLinear_select           0.660465      0.038071              0.649070
# logistic_svd               0.656047      0.042507              0.658372
# gaussian_llemodified       0.655349      0.031439              0.663023
# svcLinear_rfe              0.654419      0.044615              0.660000
# logistic                   0.653023      0.034756              0.657907
# ...                             ...           ...                   ...
# gaussian_pca               0.060465      0.004651              0.669767
# gaussian_svd               0.060465      0.004651              0.670000
# gaussian_select            0.060465      0.004651              0.657209
# gaussian                   0.060465      0.004651              0.669767
# gaussianNB_kpca            0.060465      0.004651              0.226047
#
#                       accuracy_scaled_std
# model_name
# ...

# %%
means_multinomial.sort_values(['accuracy_mean'], ascending = False)
# Out:
#                  accuracy_mean  accuracy_std  accuracy_scaled_mean  \
# model_name
# rfc_select            0.662791      0.040747              0.628372
# rfc_sel               0.661628      0.036568              0.651395
# svcLinear_pca         0.657907      0.039473              0.655814
# svcLinear_sel         0.655814      0.041078              0.656047
# svcLinear             0.655581      0.038064              0.656047
# ...                        ...           ...                   ...
# gaussian_svd          0.063256      0.008110              0.660233
# gaussianNB_kpca       0.060465      0.004651              0.164419
# gaussian_sel          0.060465      0.004651              0.669767
# gaussian_pca          0.060465      0.004651              0.670000
# gaussian              0.060465      0.004651              0.670000
#
#                  accuracy_scaled_std
# model_name
# rfc_select                  0.044306
# rfc_sel                     0.035839
# ...

# %%
std_multinomial.sort_values(['accuracy_mean'], ascending = False)
# Out:
#                         accuracy_mean  accuracy_std  accuracy_scaled_mean  \
# model_name
# gaussian_llemodified         0.626977      0.035790              0.613953
# kNeighbour_llemodified       0.617442      0.040830              0.591628
# mlp_selecttree               0.614186      0.041386              0.618140
# svcLinear_selecttree         0.611163      0.041220              0.598140
# svcLinear                    0.610000      0.039686              0.607442
# ...                               ...           ...                   ...
# gaussianNB_rfe               0.432558      0.060955              0.433721
# gaussianNB                   0.410233      0.062878              0.414651
# gaussianNB_pca               0.360233      0.049195              0.326047
# gaussianNB_select            0.352326      0.065829              0.506512
# qda_kpca                     0.294419      0.163924              0.299535
#
#                         accuracy_scaled_std
# model_name
# ...

# %% [markdown]
# ## Top classifiers in scaled accuracy

# %% [markdown]
# ### Binary data

# %%
all_binary.sort_values(['accuracy_scaled_mean'], ascending = False)
# Out:
#                       accuracy_mean  accuracy_std  accuracy_scaled_mean  \
# model_name
# logistic_kbestmutual       0.855814      0.036401              0.895116
# gaussian_kbestmutual       0.550233      0.022600              0.893721
# logistic                   0.858605      0.039009              0.891395
# logistic_sel               0.856977      0.038793              0.891395
# logistic_pca               0.860698      0.035612              0.891395
# ...                             ...           ...                   ...
# ada_kpca                   0.500000      0.000000              0.504186
# rfc_kpca                   0.500000      0.000000              0.503721
# svc_iso                    0.506279      0.011204              0.501860
# decissionTree_kpca         0.500000      0.000000              0.500930
# qda_kpca                   0.500000      0.000000              0.500000
#
#                       accuracy_scaled_std
# model_name
# ...

# %%
means_binary.sort_values(['accuracy_scaled_mean'], ascending = False)
# Out:
#                     accuracy_mean  accuracy_std  accuracy_scaled_mean  \
# model_name
# gaussian_svd             0.732326      0.041242              0.891163
# mlp                      0.813488      0.063432              0.890000
# gaussian                 0.726744      0.039892              0.890000
# gaussian_sel             0.726744      0.039892              0.890000
# gaussian_pca             0.726744      0.039892              0.890000
# ...                           ...           ...                   ...
# decissionTree_kpca       0.500000      0.000000              0.606977
# gaussianNB_kpca          0.500000      0.000000              0.568372
# qda_kpca                 0.500000      0.000000              0.546977
# rfc_kpca                 0.500000      0.000000              0.536279
# svc_iso                  0.507209      0.011367              0.516512
#
#                     accuracy_scaled_std
# model_name
# gaussian_svd                   0.032951
# ...

# %%
std_binary.sort_values(['accuracy_scaled_mean'], ascending = False)
# Out:
#                       accuracy_mean  accuracy_std  accuracy_scaled_mean  \
# model_name
# mlp_select                 0.823023      0.038234              0.826977
# mlp_selecttree             0.807907      0.038017              0.818605
# gaussian_select            0.819535      0.037516              0.818140
# gaussian_selecttree        0.808372      0.044445              0.817209
# svcLinear_selecttree       0.810465      0.035896              0.814884
# ...                             ...           ...                   ...
# qda_kpca                   0.500233      0.001628              0.539767
# decissionTree_kpca         0.500000      0.000000              0.533953
# ada_kpca                   0.500000      0.000000              0.530930
# svcLinear_kpca             0.506279      0.009924              0.527442
# rfc_kpca                   0.500000      0.000000              0.508372
#
#                       accuracy_scaled_std
# model_name
# ...

# %% [markdown]
# ### Multi-class data

# %%
all_multinomial.sort_values(['accuracy_scaled_mean'], ascending = False)
# Out:
#                      accuracy_mean  accuracy_std  accuracy_scaled_mean  \
# model_name
# logistic_selecttree       0.642558      0.041589              0.674186
# gaussian_svd              0.060465      0.004651              0.670000
# gaussian                  0.060465      0.004651              0.669767
# gaussian_pca              0.060465      0.004651              0.669767
# gaussian_sel              0.060465      0.004651              0.669535
# ...                            ...           ...                   ...
# gaussianNB_svd            0.501395      0.058123              0.470233
# ada_kpca                  0.355349      0.140272              0.453953
# decissionTree_kpca        0.482558      0.069311              0.446047
# qda_kpca                  0.287442      0.165950              0.366744
# gaussianNB_kpca           0.060465      0.004651              0.226047
#
#                      accuracy_scaled_std
# model_name
# logistic_selecttree             0.038248
# ...

# %%
means_multinomial.sort_values(['accuracy_scaled_mean'], ascending = False)
# Out:
#                       accuracy_mean  accuracy_std  accuracy_scaled_mean  \
# model_name
# mlp_rfe                    0.589070      0.053215              0.676047
# mlp_sel                    0.579767      0.055717              0.675581
# logistic_sel               0.632791      0.040621              0.674884
# mlp_pca                    0.638140      0.045846              0.674186
# gaussian_llemodified       0.646744      0.033932              0.673721
# ...                             ...           ...                   ...
# rfc_kpca                   0.500000      0.000000              0.455116
# decissionTree_kpca         0.472326      0.083426              0.454884
# ada_kpca                   0.372791      0.139058              0.409767
# qda_kpca                   0.297907      0.162789              0.334651
# gaussianNB_kpca            0.060465      0.004651              0.164419
#
#                       accuracy_scaled_std
# model_name
# ...

# %%
std_multinomial.sort_values(['accuracy_scaled_mean'], ascending = False)
# Out:
#                         accuracy_mean  accuracy_std  accuracy_scaled_mean  \
# model_name
# logistic_selecttree          0.596512      0.042771              0.623023
# mlp_select                   0.594186      0.052583              0.620465
# mlp_selecttree               0.614186      0.041386              0.618140
# logistic_select              0.581395      0.038213              0.617442
# logistic_rfe                 0.593721      0.043966              0.615349
# ...                               ...           ...                   ...
# gaussianNB_llemodified       0.564651      0.057445              0.394884
# gaussianNB_svd               0.455581      0.056998              0.347209
# gaussianNB_pca               0.360233      0.049195              0.326047
# qda_kpca                     0.294419      0.163924              0.299535
# gaussianNB_kpca              0.483256      0.079722              0.107907
#
#                         accuracy_scaled_std
# model_name
# ...

# %% [markdown]
# # Second iteration

# %% [markdown]
# ## Load data

# %% [markdown]
# ### Binary data

# %%
all_binary = pd.read_csv('../data/experiment_second_round/CV_binary_all_data.csv', index_col="model_name")
means_binary = pd.read_csv('../data/experiment_second_round/CV_binary_mean_data.csv', index_col="model_name")

# %% [markdown]
# ### Multi-class data

# %%
all_multinomial = pd.read_csv('../data/experiment_second_round/CV_multinomial_all_data.csv', index_col="model_name")
means_multinomial = pd.read_csv('../data/experiment_second_round/CV_multinomial_mean_data.csv', index_col="model_name")

# %% [markdown]
# ## Overview

# %% [markdown]
# ### Binary data

# %%
all_binary.describe()
# Out:
#        accuracy_mean  accuracy_std  accuracy_scaled_mean  accuracy_scaled_std
# count      40.000000     40.000000             40.000000            40.000000
# mean        0.795506      0.059512              0.849314             0.053695
# std         0.082385      0.009737              0.050325             0.008952
# min         0.555814      0.039943              0.638837             0.042843
# 25%         0.776453      0.053940              0.824709             0.045384
# 50%         0.817442      0.060450              0.864302             0.053127
# 75%         0.848488      0.064225              0.885872             0.058902
# max         0.868372      0.082545              0.896977             0.085413

# %%
means_binary.describe()
# Out:
#        accuracy_mean  accuracy_std  accuracy_scaled_mean  accuracy_scaled_std
# count      40.000000     40.000000             40.000000            40.000000
# mean        0.795506      0.059512              0.849314             0.053695
# std         0.082385      0.009737              0.050325             0.008952
# min         0.555814      0.039943              0.638837             0.042843
# 25%         0.776453      0.053940              0.824709             0.045384
# 50%         0.817442      0.060450              0.864302             0.053127
# 75%         0.848488      0.064225              0.885872             0.058902
# max         0.868372      0.082545              0.896977             0.085413

# %% [markdown]
# ### Multi-class data

# %%
all_multinomial.describe()
# Out:
#        accuracy_mean  accuracy_std  accuracy_scaled_mean  accuracy_scaled_std
# count      40.000000     40.000000             40.000000            40.000000
# mean        0.535413      0.059917              0.630791             0.056971
# std         0.175900      0.038465              0.048365             0.012590
# min         0.060465      0.011393              0.497907             0.013260
# 25%         0.563372      0.056249              0.614826             0.054751
# 50%         0.586744      0.060505              0.643953             0.059586
# 75%         0.634942      0.066114              0.663488             0.062778
# max         0.655814      0.258139              0.682558             0.071528

# %%
means_multinomial.describe()
# Out:
#        accuracy_mean  accuracy_std  accuracy_scaled_mean  accuracy_scaled_std
# count      40.000000     40.000000             40.000000            40.000000
# mean        0.535413      0.059917              0.630791             0.056971
# std         0.175900      0.038465              0.048365             0.012590
# min         0.060465      0.011393              0.497907             0.013260
# 25%         0.563372      0.056249              0.614826             0.054751
# 50%         0.586744      0.060505              0.643953             0.059586
# 75%         0.634942      0.066114              0.663488             0.062778
# max         0.655814      0.258139              0.682558             0.071528

# %% [markdown]
# ## Top classifiers in unscaled accuracy

# %% [markdown]
# ### Binary data

# %%
all_binary.sort_values(['accuracy_mean'], ascending = False)
# Out:
#                       accuracy_mean  accuracy_std  accuracy_scaled_mean  \
# model_name
# logistic_pca               0.868372      0.054562              0.894419
# logistic_sel               0.863488      0.054007              0.894419
# rfc_select                 0.863256      0.054765              0.808140
# logistic                   0.861395      0.057899              0.894419
# rfc_selecttree             0.860698      0.055765              0.855349
# logistic_select            0.857442      0.051966              0.878140
# logistic_rfe               0.857442      0.057405              0.863721
# mlp_pca                    0.856279      0.057001              0.885116
# logistic_selecttree        0.856047      0.049519              0.876744
# gaussian_llemodified       0.855814      0.053741              0.884651
# mlp_selecttree             0.846047      0.051666              0.894186
# rfc_rfe                    0.845116      0.053359              0.842558
# ...

# %%
means_binary.sort_values(['accuracy_mean'], ascending = False)
# Out:
#                       accuracy_mean  accuracy_std  accuracy_scaled_mean  \
# model_name
# logistic_pca               0.868372      0.054562              0.894419
# logistic_sel               0.863488      0.054007              0.894419
# rfc_select                 0.863256      0.054765              0.808140
# logistic                   0.861395      0.057899              0.894419
# rfc_selecttree             0.860698      0.055765              0.855349
# logistic_select            0.857442      0.051966              0.878140
# logistic_rfe               0.857442      0.057405              0.863721
# mlp_pca                    0.856279      0.057001              0.885116
# logistic_selecttree        0.856047      0.049519              0.876744
# gaussian_llemodified       0.855814      0.053741              0.884651
# mlp_selecttree             0.846047      0.051666              0.894186
# rfc_rfe                    0.845116      0.053359              0.842558
# ...

# %% [markdown]
# ### Multi-class data

# %%
all_multinomial.sort_values(['accuracy_mean'], ascending = False)
# Out:
#                       accuracy_mean  accuracy_std  accuracy_scaled_mean  \
# model_name
# logistic                   0.655814      0.062054              0.663721
# logistic_sel               0.653488      0.062791              0.663488
# rfc_select                 0.652093      0.056481              0.622093
# gaussian_llemodified       0.650930      0.059518              0.662093
# rfc_selecttree             0.648140      0.059259              0.646512
# mlp_pca                    0.645814      0.065270              0.673256
# logistic_selecttree        0.643721      0.060544              0.676512
# rfc_sel                    0.640698      0.058035              0.635581
# rfc                        0.638140      0.064893              0.637674
# logistic_select            0.637907      0.056032              0.658372
# rfc_rfe                    0.633953      0.057402              0.636279
# logistic_pca               0.625116      0.060490              0.663488
# ...

# %%
means_multinomial.sort_values(['accuracy_mean'], ascending = False)
# Out:
#                       accuracy_mean  accuracy_std  accuracy_scaled_mean  \
# model_name
# logistic                   0.655814      0.062054              0.663721
# logistic_sel               0.653488      0.062791              0.663488
# rfc_select                 0.652093      0.056481              0.622093
# gaussian_llemodified       0.650930      0.059518              0.662093
# rfc_selecttree             0.648140      0.059259              0.646512
# mlp_pca                    0.645814      0.065270              0.673256
# logistic_selecttree        0.643721      0.060544              0.676512
# rfc_sel                    0.640698      0.058035              0.635581
# rfc                        0.638140      0.064893              0.637674
# logistic_select            0.637907      0.056032              0.658372
# rfc_rfe                    0.633953      0.057402              0.636279
# logistic_pca               0.625116      0.060490              0.663488
# ...

# %% [markdown]
# ## Top classifiers in scaled accuracy

# %% [markdown]
# ### Binary data

# %%
all_binary.sort_values(['accuracy_scaled_mean'], ascending = False)
# Out:
#                       accuracy_mean  accuracy_std  accuracy_scaled_mean  \
# model_name
# gaussian_sel               0.555814      0.039943              0.896977
# gaussian                   0.555814      0.039943              0.896977
# gaussian_pca               0.555814      0.039943              0.896977
# logistic                   0.861395      0.057899              0.894419
# logistic_pca               0.868372      0.054562              0.894419
# logistic_sel               0.863488      0.054007              0.894419
# mlp_selecttree             0.846047      0.051666              0.894186
# gaussian_selecttree        0.813023      0.082545              0.890930
# mlp_sel                    0.821860      0.064215              0.888372
# mlp                        0.830465      0.062859              0.888140
# mlp_pca                    0.856279      0.057001              0.885116
# gaussian_llemodified       0.855814      0.053741              0.884651
# ...

# %%
means_binary.sort_values(['accuracy_scaled_mean'], ascending = False)
# Out:
#                       accuracy_mean  accuracy_std  accuracy_scaled_mean  \
# model_name
# gaussian_sel               0.555814      0.039943              0.896977
# gaussian                   0.555814      0.039943              0.896977
# gaussian_pca               0.555814      0.039943              0.896977
# logistic                   0.861395      0.057899              0.894419
# logistic_pca               0.868372      0.054562              0.894419
# logistic_sel               0.863488      0.054007              0.894419
# mlp_selecttree             0.846047      0.051666              0.894186
# gaussian_selecttree        0.813023      0.082545              0.890930
# mlp_sel                    0.821860      0.064215              0.888372
# mlp                        0.830465      0.062859              0.888140
# mlp_pca                    0.856279      0.057001              0.885116
# gaussian_llemodified       0.855814      0.053741              0.884651
# ...

# %% [markdown]
# ### Multi-class data

# %%
all_multinomial.sort_values(['accuracy_scaled_mean'], ascending = False)
# Out:
#                       accuracy_mean  accuracy_std  accuracy_scaled_mean  \
# model_name
# mlp_selecttree             0.607907      0.067243              0.682558
# gaussian_pca               0.060465      0.011393              0.678372
# gaussian_sel               0.060465      0.011393              0.678372
# gaussian                   0.060465      0.011393              0.678372
# logistic_selecttree        0.643721      0.060544              0.676512
# mlp_sel                    0.586047      0.062661              0.674419
# mlp_pca                    0.645814      0.065270              0.673256
# mlp                        0.585116      0.065919              0.670698
# logistic                   0.655814      0.062054              0.663721
# logistic_pca               0.625116      0.060490              0.663488
# logistic_sel               0.653488      0.062791              0.663488
# mlp_rfe                    0.605116      0.067159              0.663256
# ...

# %%
means_multinomial.sort_values(['accuracy_scaled_mean'], ascending = False)
# Out:
#                       accuracy_mean  accuracy_std  accuracy_scaled_mean  \
# model_name
# mlp_selecttree             0.607907      0.067243              0.682558
# gaussian_pca               0.060465      0.011393              0.678372
# gaussian_sel               0.060465      0.011393              0.678372
# gaussian                   0.060465      0.011393              0.678372
# logistic_selecttree        0.643721      0.060544              0.676512
# mlp_sel                    0.586047      0.062661              0.674419
# mlp_pca                    0.645814      0.065270              0.673256
# mlp                        0.585116      0.065919              0.670698
# logistic                   0.655814      0.062054              0.663721
# logistic_pca               0.625116      0.060490              0.663488
# logistic_sel               0.653488      0.062791              0.663488
# mlp_rfe                    0.605116      0.067159              0.663256
# ...
