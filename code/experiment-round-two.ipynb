# %% [markdown]
# # Second round of model selection

# %%
import numpy as np
import pandas as pd

from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.ensemble import RandomForestClassifier

from sklearn.manifold import LocallyLinearEmbedding
from sklearn.decomposition import PCA

from sklearn.feature_selection import VarianceThreshold
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif
from sklearn.feature_selection import mutual_info_classif
from sklearn.feature_selection import SelectFromModel
from sklearn.svm import LinearSVC
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.feature_selection import RFE
from sklearn.tree import DecisionTreeClassifier

from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv('../data/train_data.csv')

X = df.drop(['class4', 'class2'], axis=1)
X_means = X.loc[:, X.columns[range(2, X.shape[1], 2)]]

X_scaled = pd.DataFrame(StandardScaler().fit_transform(X), columns = X.columns)
X_scaled_means = X_scaled.loc[:, X.columns[range(2, X.shape[1], 2)]]

y_class2 = df['class2']
y_class4 = df['class4']

# %% [markdown]
# ## Classifiers

# %%
classifiers = [
    ('logistic', LogisticRegression()),
    ('gaussian', GaussianProcessClassifier(1.0 * RBF(1.0))),
    ('rfc', RandomForestClassifier(max_depth=5, n_estimators=10, max_features=1)),
    ('mlp', MLPClassifier(alpha=1, max_iter=1000))]

# %% [markdown]
# ## Functions

# %%
def k_fold_cross_validation(ml_pipeline, X, y, n=10, k=10, score='accuracy'):
    """Perform N repeated K-fold cross-validation

    Keyword arguments:
    ml_pipeline -- Intance of scikit-learn's Pipeline
    X -- Data to perform cross-validation
    y -- Labels of the data
    n -- Amount of times cross-validation is repeated (default is 10)
    k -- Amount of folds that the data is splitted to perform 
         cross-validation (default is 10)
    score -- Scoring type as a string for scikit-learn's 
             cross_val_score method (default is accuracy)
    
    Return:
    Two element numpy array where first value is mean of cross-validation scores
    and second is standard deviation of cross-validation scores.
    """
    cv = RepeatedStratifiedKFold(n_splits = n, 
                                 n_repeats = k, 
                                 random_state = 1)
    n_scores = cross_val_score(ml_pipeline, X, y, 
                               scoring = score, cv = cv, 
                               n_jobs = -1)
    
    return(np.array([np.mean(n_scores), np.std(n_scores)]))

# %% [markdown]
# ## Entire data set

# %% [markdown]
# ### Dimensionality reduction techinques

# %%
# Variance boundry for VarianceThreshold
# More info: https://scikit-learn.org/stable/modules/feature_selection.html#variance-threshold
p = 0.7
variance = p * (1 - p)

# %%
dimension_reductions_y2 = [
    ('lle', LocallyLinearEmbedding(n_components=31)), 
    ('llemodified', LocallyLinearEmbedding(n_components=31, method='modified', n_neighbors=90)),
    ('pca', PCA()),
    ('sel', VarianceThreshold(threshold=variance)),
    ('kbest', SelectKBest(f_classif, k=63)), 
    ('kbestmutual', SelectKBest(mutual_info_classif, k=90)),
    ('select', SelectFromModel(LinearSVC(penalty="l2"))),
    ('selectree', SelectFromModel(ExtraTreesClassifier(n_estimators=45))),
    ('rfe', RFE(estimator=DecisionTreeClassifier(), n_features_to_select=70))]

dimension_reductions_y4 = [
    ('lle', LocallyLinearEmbedding(n_components=50)), 
    ('llemodified', LocallyLinearEmbedding(n_components=50, method='modified', n_neighbors=90)),
    ('pca', PCA()),
    ('sel', VarianceThreshold(threshold=variance)),
    ('kbest', SelectKBest(f_classif, k=20)), 
    ('kbestmutual', SelectKBest(mutual_info_classif, k=40)),
    ('select', SelectFromModel(LinearSVC(penalty="l2"))),
    ('selecttree', SelectFromModel(ExtraTreesClassifier(n_estimators=70))),
    ('rfe', RFE(estimator=DecisionTreeClassifier(), n_features_to_select=50))]

# %% [markdown]
# ### Computations

# %%
columns = ['accuracy_mean', 'accuracy_std', 
           'accuracy_scaled_mean', 'accuracy_scaled_std']
statistics_y2 = pd.DataFrame(index = columns)
statistics_y4 = pd.DataFrame(index = columns)

# %% [markdown]
# #### Binary

# %%
y = y_class2

for model_used in classifiers:
    model = Pipeline([model_used])

    not_scaled = k_fold_cross_validation(model, X, y)
    scaled = k_fold_cross_validation(model, X_scaled, y)

    data = np.concatenate((not_scaled, scaled))
    statistics_y2[ model_used[0] ] = data

    for feature_selection in dimension_reductions_y2:
        model = Pipeline([feature_selection, model_used])

        not_scaled = k_fold_cross_validation(model, X, y)
        scaled = k_fold_cross_validation(model, X_scaled, y)

        column = model_used[0] + '_' + feature_selection[0]
        data = np.concatenate((not_scaled, scaled))
        statistics_y2[ column ] = data

# %%
statistics_transpose_y2 = statistics_y2.transpose(copy=True)
statistics_transpose_y2
# Out:
#                       accuracy_mean  accuracy_std  accuracy_scaled_mean  \
# logistic                   0.861395      0.057899              0.894419
# logistic_lle               0.784884      0.059325              0.853721
# logistic_llemodified       0.866512      0.052686              0.875349
# logistic_pca               0.868372      0.054562              0.894419
# logistic_sel               0.863488      0.054007              0.894419
# logistic_kbest             0.868140      0.058377              0.891395
# logistic_kbestmutual       0.863023      0.055219              0.898140
# logistic_select            0.859070      0.054423              0.878372
# logistic_selectree         0.858837      0.053565              0.882326
# logistic_rfe               0.862558      0.052011              0.877674
# gaussian                   0.555814      0.039943              0.896977
# gaussian_lle               0.777674      0.064223              0.854419
# gaussian_llemodified       0.867442      0.051741              0.885116
# gaussian_pca               0.555814      0.039943              0.896977
# gaussian_sel               0.555814      0.039943              0.896977
# gaussian_kbest             0.576279      0.052886              0.787907
# gaussian_kbestmutual       0.554419      0.041565              0.900698
# gaussian_select            0.768372      0.060547              0.882791
# gaussian_selectree         0.779070      0.091941              0.889070
# gaussian_rfe               0.667209      0.093412              0.826744
# rfc                        0.833023      0.061738              0.832791
# rfc_lle                    0.768605      0.066787              0.818837
# rfc_llemodified            0.760000      0.065106              0.760465
# rfc_pca                    0.623953      0.083466              0.636047
# rfc_sel                    0.836512      0.060773              0.832791
# rfc_kbest                  0.843023      0.053374              0.832791
# rfc_kbestmutual            0.834651      0.061608              0.835814
# rfc_select                 0.864419      0.052935              0.806512
# rfc_selectree              0.859535      0.050836              0.859767
# rfc_rfe                    0.836047      0.060944              0.829070
# mlp                        0.827442      0.068609              0.887209
# mlp_lle                    0.784419      0.061516              0.853256
# mlp_llemodified            0.866744      0.053524              0.879302
# mlp_pca                    0.854651      0.051202              0.890000
# mlp_sel                    0.828140      0.058823              0.886744
# mlp_kbest                  0.830698      0.059389              0.890465
# mlp_kbestmutual            0.834419      0.065388              0.891860
# mlp_select                 0.845349      0.065808              0.886047
# mlp_selectree              0.846512      0.055522              0.891163
# mlp_rfe                    0.842326      0.059161              0.881163
#
#                       accuracy_scaled_std
# logistic                         0.045384
# logistic_lle                     0.052032
# logistic_llemodified             0.049280
# logistic_pca                     0.045384
# logistic_sel                     0.045384
# logistic_kbest                   0.046634
# logistic_kbestmutual             0.045901
# logistic_select                  0.052090
# logistic_selectree               0.049203
# logistic_rfe                     0.049401
# gaussian                         0.043040
# gaussian_lle                     0.054996
# gaussian_llemodified             0.044469
# gaussian_pca                     0.043040
# gaussian_sel                     0.043040
# gaussian_kbest                   0.181463
# gaussian_kbestmutual             0.044595
# gaussian_select                  0.044845
# gaussian_selectree               0.047530
# gaussian_rfe                     0.143900
# rfc                              0.065091
# rfc_lle                          0.055160
# rfc_llemodified                  0.073136
# rfc_pca                          0.081586
# rfc_sel                          0.062635
# rfc_kbest                        0.062721
# rfc_kbestmutual                  0.055016
# rfc_select                       0.066422
# rfc_selectree                    0.055078
# rfc_rfe                          0.062694
# mlp                              0.040464
# mlp_lle                          0.052384
# mlp_llemodified                  0.049190
# mlp_pca                          0.041971
# mlp_sel                          0.044933
# mlp_kbest                        0.044405
# mlp_kbestmutual                  0.042038
# mlp_select                       0.046337
# mlp_selectree                    0.044476
# mlp_rfe                          0.047535

# %%
statistics_transpose_y2.describe()
# Out:
#        accuracy_mean  accuracy_std  accuracy_scaled_mean  accuracy_scaled_std
# count      40.000000     40.000000             40.000000            40.000000
# mean        0.795506      0.059512              0.849314             0.053695
# std         0.082385      0.009737              0.050325             0.008952
# min         0.555814      0.039943              0.638837             0.042843
# 25%         0.776453      0.053940              0.824709             0.045384
# 50%         0.817442      0.060450              0.864302             0.053127
# 75%         0.848488      0.064225              0.885872             0.058902
# max         0.868372      0.082545              0.896977             0.085413

# %% [markdown]
# #### multi-class

# %%
y = y_class4

for model_used in classifiers:
    model = Pipeline([model_used])

    not_scaled = k_fold_cross_validation(model, X, y)
    scaled = k_fold_cross_validation(model, X_scaled, y)

    data = np.concatenate((not_scaled, scaled))
    statistics_y4[ model_used[0] ] = data

    for feature_selection in dimension_reductions_y4:
        model = Pipeline([feature_selection, model_used])

        not_scaled = k_fold_cross_validation(model, X, y)
        scaled = k_fold_cross_validation(model, X_scaled, y)

        column = model_used[0] + '_' + feature_selection[0]
        data = np.concatenate((not_scaled, scaled))
        statistics_y4[ column ] = data

# %%
statistics_transpose_y4 = statistics_y4.transpose(copy=True)
statistics_transpose_y4
# Out:
#                       accuracy_mean  accuracy_std  accuracy_scaled_mean  \
# logistic                   0.655814      0.062054              0.663721
# logistic_lle               0.500465      0.015937              0.505814
# logistic_llemodified       0.512558      0.020780              0.510465
# logistic_pca               0.625116      0.060490              0.663488
# logistic_sel               0.653488      0.062791              0.663488
# logistic_kbest             0.588837      0.067151              0.614419
# logistic_kbestmutual       0.650465      0.061481              0.665116
# logistic_select            0.634651      0.056898              0.656047
# logistic_selecttree        0.641860      0.060911              0.677442
# logistic_rfe               0.649767      0.062818              0.659070
# gaussian                   0.060465      0.011393              0.678372
# gaussian_lle               0.573023      0.061222              0.666977
# gaussian_llemodified       0.649535      0.053261              0.666977
# gaussian_pca               0.060465      0.011393              0.678372
# gaussian_sel               0.060465      0.011393              0.678372
# gaussian_kbest             0.564419      0.106106              0.600233
# gaussian_kbestmutual       0.064651      0.014177              0.653488
# gaussian_select            0.060465      0.011393              0.660465
# gaussian_selecttree        0.154419      0.189203              0.652791
# gaussian_rfe               0.060698      0.011810              0.659302
# rfc                        0.638837      0.057008              0.625814
# rfc_lle                    0.548837      0.061088              0.585116
# rfc_llemodified            0.518140      0.030514              0.511163
# rfc_pca                    0.503721      0.035608              0.497674
# rfc_sel                    0.637442      0.062583              0.631860
# rfc_kbest                  0.566279      0.067432              0.576047
# rfc_kbestmutual            0.639767      0.060330              0.639535
# rfc_select                 0.654419      0.054838              0.614419
# rfc_selecttree             0.639535      0.058879              0.642326
# rfc_rfe                    0.645349      0.063805              0.645581
# mlp                        0.586512      0.062018              0.675116
# mlp_lle                    0.571163      0.059502              0.669535
# mlp_llemodified            0.642093      0.054826              0.669302
# mlp_pca                    0.645814      0.067149              0.678140
# mlp_sel                    0.583721      0.061661              0.671163
# mlp_kbest                  0.560698      0.061520              0.611628
# mlp_kbestmutual            0.587442      0.054004              0.669070
# mlp_select                 0.606047      0.066580              0.652093
# mlp_selecttree             0.615116      0.065644              0.666047
# mlp_rfe                    0.588837      0.074119              0.672326
#
#                       accuracy_scaled_std
# logistic                         0.059964
# logistic_lle                     0.015205
# logistic_llemodified             0.018126
# logistic_pca                     0.059877
# logistic_sel                     0.059967
# logistic_kbest                   0.059125
# logistic_kbestmutual             0.064448
# logistic_select                  0.072898
# logistic_selecttree              0.066241
# logistic_rfe                     0.068533
# gaussian                         0.059569
# gaussian_lle                     0.059371
# gaussian_llemodified             0.055705
# gaussian_pca                     0.059569
# gaussian_sel                     0.059569
# gaussian_kbest                   0.065174
# gaussian_kbestmutual             0.042692
# gaussian_select                  0.046278
# gaussian_selecttree              0.045125
# gaussian_rfe                     0.045140
# rfc                              0.057447
# rfc_lle                          0.046011
# rfc_llemodified                  0.033213
# rfc_pca                          0.038071
# rfc_sel                          0.060559
# rfc_kbest                        0.073457
# rfc_kbestmutual                  0.062877
# rfc_select                       0.062070
# rfc_selecttree                   0.057417
# rfc_rfe                          0.060027
# mlp                              0.061393
# mlp_lle                          0.060133
# mlp_llemodified                  0.048177
# mlp_pca                          0.058531
# mlp_sel                          0.054243
# mlp_kbest                        0.069027
# mlp_kbestmutual                  0.061340
# mlp_select                       0.058364
# mlp_selecttree                   0.065573
# mlp_rfe                          0.058934

# %%
statistics_transpose_y4.describe()
# Out:
#        accuracy_mean  accuracy_std  accuracy_scaled_mean  accuracy_scaled_std
# count      40.000000     40.000000             40.000000            40.000000
# mean        0.535413      0.059917              0.630791             0.056971
# std         0.175900      0.038465              0.048365             0.012590
# min         0.060465      0.011393              0.497907             0.013260
# 25%         0.563372      0.056249              0.614826             0.054751
# 50%         0.586744      0.060505              0.643953             0.059586
# 75%         0.634942      0.066114              0.663488             0.062778
# max         0.655814      0.258139              0.682558             0.071528

# %% [markdown]
# #### Save results

# %%
statistics_transpose_y2.to_csv('../data/experiment_second_round/CV_binary_all_data.csv', index_label="model_name")
statistics_transpose_y4.to_csv('../data/experiment_second_round/CV_multinomial_all_data.csv', index_label="model_name")

# %% [markdown]
# ## Mean data set

# %% [markdown]
# ### Dimensionality reduction techinques

# %%
# Variance boundry for VarianceThreshold
# More info: https://scikit-learn.org/stable/modules/feature_selection.html#variance-threshold
p = 0.7
variance = p * (1 - p)

# %%
dimension_reductions_y2 = [
    ('lle', LocallyLinearEmbedding(n_components=10)), 
    ('llemodified', LocallyLinearEmbedding(n_components=10, method='modified', n_neighbors=90)),
    ('pca', PCA()),
    ('sel', VarianceThreshold(threshold=variance)),
    ('kbest', SelectKBest(f_classif, k=10)), 
    ('kbestmutual', SelectKBest(mutual_info_classif, k=10)),
    ('select', SelectFromModel(LinearSVC(penalty="l2"))),
    ('selecttree', SelectFromModel(ExtraTreesClassifier(n_estimators=20))),
    ('rfe', RFE(estimator=DecisionTreeClassifier(), n_features_to_select=20))]

dimension_reductions_y4 = [
    ('lle', LocallyLinearEmbedding(n_components=10)), 
    ('llemodified', LocallyLinearEmbedding(n_components=10, method='modified', n_neighbors=90)),
    ('pca', PCA()),
    ('sel', VarianceThreshold(threshold=variance)),
    ('kbest', SelectKBest(f_classif, k=10)), 
    ('kbestmutual', SelectKBest(mutual_info_classif, k=10)),
    ('select', SelectFromModel(LinearSVC(penalty="l2"))),
    ('selecttree', SelectFromModel(ExtraTreesClassifier(n_estimators=10))),
    ('rfe', RFE(estimator=DecisionTreeClassifier(), n_features_to_select=10))]

# %% [markdown]
# ### Computations

# %%
columns = ['accuracy_mean', 'accuracy_std', 
           'accuracy_scaled_mean', 'accuracy_scaled_std']
statistics_y2 = pd.DataFrame(index = columns)
statistics_y4 = pd.DataFrame(index = columns)

# %% [markdown]
# #### Binary

# %%
y = y_class2

for model_used in classifiers:
    model = Pipeline([model_used])

    not_scaled = k_fold_cross_validation(model, X, y)
    scaled = k_fold_cross_validation(model, X_scaled, y)

    data = np.concatenate((not_scaled, scaled))
    statistics_y2[ model_used[0] ] = data

    for feature_selection in dimension_reductions_y2:
        model = Pipeline([feature_selection, model_used])

        not_scaled = k_fold_cross_validation(model, X, y)
        scaled = k_fold_cross_validation(model, X_scaled, y)

        column = model_used[0] + '_' + feature_selection[0]
        data = np.concatenate((not_scaled, scaled))
        statistics_y2[ column ] = data

# %%
statistics_transpose_y2 = statistics_y2.transpose(copy=True)
statistics_transpose_y2
# Out:
#                       accuracy_mean  accuracy_std  accuracy_scaled_mean  \
# logistic                   0.861395      0.057899              0.894419
# logistic_lle               0.766977      0.064531              0.845581
# logistic_llemodified       0.833953      0.051059              0.864884
# logistic_pca               0.868372      0.054562              0.894419
# logistic_sel               0.863488      0.054007              0.894419
# logistic_kbest             0.797209      0.061272              0.807907
# logistic_kbestmutual       0.789302      0.060090              0.794419
# logistic_select            0.857442      0.051966              0.878140
# logistic_selecttree        0.856047      0.049519              0.876744
# logistic_rfe               0.857442      0.057405              0.863721
# gaussian                   0.555814      0.039943              0.896977
# gaussian_lle               0.764186      0.062143              0.848372
# gaussian_llemodified       0.855814      0.053741              0.884651
# gaussian_pca               0.555814      0.039943              0.896977
# gaussian_sel               0.555814      0.039943              0.896977
# gaussian_kbest             0.808605      0.060809              0.802326
# gaussian_kbestmutual       0.790000      0.062873              0.795814
# gaussian_select            0.767907      0.062053              0.882791
# gaussian_selecttree        0.813023      0.082545              0.890930
# gaussian_rfe               0.812558      0.071892              0.879070
# rfc                        0.833953      0.066107              0.832093
# rfc_lle                    0.760233      0.065422              0.830233
# rfc_llemodified            0.809070      0.060937              0.838372
# rfc_pca                    0.632558      0.081429              0.638837
# rfc_sel                    0.840698      0.055168              0.834419
# rfc_kbest                  0.786977      0.064257              0.792093
# rfc_kbestmutual            0.779302      0.058787              0.778837
# rfc_select                 0.863256      0.054765              0.808140
# rfc_selecttree             0.860698      0.055765              0.855349
# rfc_rfe                    0.845116      0.053359              0.842558
# mlp                        0.830465      0.062859              0.888140
# mlp_lle                    0.767209      0.063731              0.847442
# mlp_llemodified            0.837674      0.050415              0.866279
# mlp_pca                    0.856279      0.057001              0.885116
# mlp_sel                    0.821860      0.064215              0.888372
# mlp_kbest                  0.780465      0.065474              0.804419
# mlp_kbestmutual            0.766047      0.066661              0.794884
# mlp_select                 0.840000      0.062079              0.883953
# mlp_selecttree             0.846047      0.051666              0.894186
# mlp_rfe                    0.831163      0.082197              0.879302
#
#                       accuracy_scaled_std
# logistic                         0.045384
# logistic_lle                     0.056442
# logistic_llemodified             0.051866
# logistic_pca                     0.045384
# logistic_sel                     0.045384
# logistic_kbest                   0.058058
# logistic_kbestmutual             0.062030
# logistic_select                  0.051175
# logistic_selecttree              0.053082
# logistic_rfe                     0.054937
# gaussian                         0.043040
# gaussian_lle                     0.056438
# gaussian_llemodified             0.050301
# gaussian_pca                     0.043040
# gaussian_sel                     0.043040
# gaussian_kbest                   0.058879
# gaussian_kbestmutual             0.061492
# gaussian_select                  0.044481
# gaussian_selecttree              0.049845
# gaussian_rfe                     0.051793
# rfc                              0.062018
# rfc_lle                          0.058971
# rfc_llemodified                  0.053171
# rfc_pca                          0.085413
# rfc_sel                          0.058767
# rfc_kbest                        0.065433
# rfc_kbestmutual                  0.063561
# rfc_select                       0.067991
# rfc_selecttree                   0.053294
# rfc_rfe                          0.058820
# mlp                              0.042843
# mlp_lle                          0.055845
# mlp_llemodified                  0.051728
# mlp_pca                          0.043485
# mlp_sel                          0.043258
# mlp_kbest                        0.059573
# mlp_kbestmutual                  0.062087
# mlp_select                       0.046102
# mlp_selecttree                   0.044899
# mlp_rfe                          0.044454

# %%
statistics_transpose_y2.describe()
# Out:
#        accuracy_mean  accuracy_std  accuracy_scaled_mean  accuracy_scaled_std
# count      40.000000     40.000000             40.000000            40.000000
# mean        0.795506      0.059512              0.849314             0.053695
# std         0.082385      0.009737              0.050325             0.008952
# min         0.555814      0.039943              0.638837             0.042843
# 25%         0.776453      0.053940              0.824709             0.045384
# 50%         0.817442      0.060450              0.864302             0.053127
# 75%         0.848488      0.064225              0.885872             0.058902
# max         0.868372      0.082545              0.896977             0.085413

# %% [markdown]
# #### multi-class

# %%
y = y_class4

for model_used in classifiers:
    model = Pipeline([model_used])

    not_scaled = k_fold_cross_validation(model, X, y)
    scaled = k_fold_cross_validation(model, X_scaled, y)

    data = np.concatenate((not_scaled, scaled))
    statistics_y4[ model_used[0] ] = data

    for feature_selection in dimension_reductions_y4:
        model = Pipeline([feature_selection, model_used])

        not_scaled = k_fold_cross_validation(model, X, y)
        scaled = k_fold_cross_validation(model, X_scaled, y)

        column = model_used[0] + '_' + feature_selection[0]
        data = np.concatenate((not_scaled, scaled))
        statistics_y4[ column ] = data

# %%
statistics_transpose_y4 = statistics_y4.transpose(copy=True)
statistics_transpose_y4
# Out:
#                       accuracy_mean  accuracy_std  accuracy_scaled_mean  \
# logistic                   0.655814      0.062054              0.663721
# logistic_lle               0.500000      0.011628              0.501628
# logistic_llemodified       0.503488      0.014477              0.510000
# logistic_pca               0.625116      0.060490              0.663488
# logistic_sel               0.653488      0.062791              0.663488
# logistic_kbest             0.587442      0.060521              0.585349
# logistic_kbestmutual       0.600930      0.067219              0.623488
# logistic_select            0.637907      0.056032              0.658372
# logistic_selecttree        0.643721      0.060544              0.676512
# logistic_rfe               0.623721      0.057096              0.648605
# gaussian                   0.060465      0.011393              0.678372
# gaussian_lle               0.565581      0.057426              0.641860
# gaussian_llemodified       0.650930      0.059518              0.662093
# gaussian_pca               0.060465      0.011393              0.678372
# gaussian_sel               0.060465      0.011393              0.678372
# gaussian_kbest             0.584884      0.066706              0.593953
# gaussian_kbestmutual       0.578140      0.070998              0.609302
# gaussian_select            0.060465      0.011393              0.659767
# gaussian_selecttree        0.220698      0.258139              0.661163
# gaussian_rfe               0.616279      0.113716              0.646047
# rfc                        0.638140      0.064893              0.637674
# rfc_lle                    0.547209      0.064150              0.615349
# rfc_llemodified            0.585349      0.057065              0.613256
# rfc_pca                    0.498605      0.037832              0.497907
# rfc_sel                    0.640698      0.058035              0.635581
# rfc_kbest                  0.567907      0.064464              0.564186
# rfc_kbestmutual            0.564419      0.069988              0.563953
# rfc_select                 0.652093      0.056481              0.622093
# rfc_selecttree             0.648140      0.059259              0.646512
# rfc_rfe                    0.633953      0.057402              0.636279
# mlp                        0.585116      0.065919              0.670698
# mlp_lle                    0.572326      0.051782              0.630930
# mlp_llemodified            0.606512      0.044574              0.636512
# mlp_pca                    0.645814      0.065270              0.673256
# mlp_sel                    0.586047      0.062661              0.674419
# mlp_kbest                  0.574651      0.066700              0.586047
# mlp_kbestmutual            0.560233      0.074571              0.616047
# mlp_select                 0.606279      0.056321              0.661163
# mlp_selecttree             0.607907      0.067243              0.682558
# mlp_rfe                    0.605116      0.067159              0.663256
#
#                       accuracy_scaled_std
# logistic                         0.059964
# logistic_lle                     0.013260
# logistic_llemodified             0.018090
# logistic_pca                     0.059877
# logistic_sel                     0.059967
# logistic_kbest                   0.057912
# logistic_kbestmutual             0.070897
# logistic_select                  0.070515
# logistic_selecttree              0.061273
# logistic_rfe                     0.063082
# gaussian                         0.059569
# gaussian_lle                     0.057813
# gaussian_llemodified             0.056244
# gaussian_pca                     0.059569
# gaussian_sel                     0.059569
# gaussian_kbest                   0.065482
# gaussian_kbestmutual             0.069534
# gaussian_select                  0.044933
# gaussian_selecttree              0.048253
# gaussian_rfe                     0.054597
# rfc                              0.062677
# rfc_lle                          0.059602
# rfc_llemodified                  0.054802
# rfc_pca                          0.028878
# rfc_sel                          0.058191
# rfc_kbest                        0.071044
# rfc_kbestmutual                  0.069017
# rfc_select                       0.061738
# rfc_selecttree                   0.061088
# rfc_rfe                          0.059883
# mlp                              0.058438
# mlp_lle                          0.047735
# mlp_llemodified                  0.047507
# mlp_pca                          0.052558
# mlp_sel                          0.057060
# mlp_kbest                        0.071528
# mlp_kbestmutual                  0.066716
# mlp_select                       0.062337
# mlp_selecttree                   0.053577
# mlp_rfe                          0.064068

# %%
statistics_transpose_y4.describe()
# Out:
#        accuracy_mean  accuracy_std  accuracy_scaled_mean  accuracy_scaled_std
# count      40.000000     40.000000             40.000000            40.000000
# mean        0.535413      0.059917              0.630791             0.056971
# std         0.175900      0.038465              0.048365             0.012590
# min         0.060465      0.011393              0.497907             0.013260
# 25%         0.563372      0.056249              0.614826             0.054751
# 50%         0.586744      0.060505              0.643953             0.059586
# 75%         0.634942      0.066114              0.663488             0.062778
# max         0.655814      0.258139              0.682558             0.071528

# %% [markdown]
# #### Save results

# %%
statistics_transpose_y2.to_csv('../data/experiment_second_round/CV_binary_mean_data.csv', index_label="model_name")
statistics_transpose_y4.to_csv('../data/experiment_second_round/CV_multinomial_mean_data.csv', index_label="model_name")
